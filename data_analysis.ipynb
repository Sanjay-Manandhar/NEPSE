# %%
import pandas as pd
import requests as ro
from bs4 import BeautifulSoup as bs



import numpy as np

# %%
data_url = pd.read_html("http://www.nepalstock.com/main/stockwiseprices/index/2/?startDate=2000-01-17&endDate=&stock-symbol=130&_limit=20000000")

# %%
url = "http://www.nepalstock.com/main/stockwiseprices/index/2/?startDate=2000-01-17&endDate=&stock-symbol=131&_limit=20000000"
data_string = url.split("/")[-1:]

# %%
data_file = pd.read_csv("/home/sanja/Downloads/id - Sheet.csv", header= None   )
data_file.rename(columns={0:'Id', 1: 'Name'}, inplace= True)

data_file
# Out:
#        Id   Name
# 0     131  NABIL
# 1     132    NIB
# 2     133    SCB
# 3     134    NaN
# 4     135    SBI
# ..    ...    ...
# 421  2914   UMRH
# 422  2915    PLI
# 423  2917    CGH
# 424  2919  NIFRA
# 425   156    BBC
#
# [426 rows x 2 columns]

# %%
#data_file.loc[0].dtypes
#data_file.loc[0].astype(int)

# %%
data_file['Id'].value_counts()
# Out:
# 156     2
# 131     1
# 712     1
# 726     1
# 725     1
#        ..
# 400     1
# 398     1
# 397     1
# 396     1
# 2919    1
# Name: Id, Length: 425, dtype: int64

# %%
var_1 = data_file.loc[:,["Id" ]]
d = {}

for  index_value in range(len(var_1)):
      url_id = var_1.loc[index_value,"Id"]
      
      url = "http://www.nepalstock.com/main/stockwiseprices/index/2/?startDate=2000-01-17&endDate=&stock-symbol="+str(url_id)+"&_limit=20000000"
      #print(url)
      d[url_id] = pd.read_html(url)
      
      

      #print(index_value)
#var_1.loc[5]
print(d)
#print(var_1.dtyes)
# Out:
# {131: [                                                      0  \
# 0     Nabil Bank Limited Start Date  End Date  Stock...
# 1                                                  S.N.
# 2                                                     1
# 3                                                     2
# 4                                                     3
# ...                                                 ...
# 2619                                               2618
# 2620                                               2619
# 2621                                               2620
# 2622                                               2621
# 2623                                         Page 1/1 1
#
#                                                       1  \
# 0     Nabil Bank Limited Start Date  End Date  Stock...
# 1                                                  Date
# 2                                            2021-11-18
# ...

# %%
type(d[131][0])
# Out:
# pandas.core.frame.DataFrame

# %%
# Out:
#                                                       0  \
# 0     Standard Chartered Bank Limited Start Date  En...
# 1                                                  S.N.
# 2                                                     1
# 3                                                     2
# 4                                                     3
# ...                                                 ...
# 2630                                               2629
# 2631                                               2630
# 2632                                               2631
# 2633                                               2632
# 2634                                         Page 1/1 1
#
#                                                       1  \
# 0     Standard Chartered Bank Limited Start Date  En...
# 1                                                  Date
# 2                                            2021-11-18
# 3                                            2021-11-17
# ...

# %%
import mysql.connector
from mysql.connector import Error

# %%
try:
    connection = mysql.connector.connect(host='localhost',
                                         database='testdb',
                                         user='root',
                                         password='Manandhar123$')
    
    if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version ", db_Info)
        cursor = connection.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)

except Error as e:
    print("Error while connecting to MySQL", e)
finally:
    if connection.is_connected():
        #cursor.close()
        #connection.close()
        #print("MySQL connection is closed")
        pass

# %%
select_table_compay = "SELECT * From company"
with connection.cursor() as cursor:
  cursor.execute(select_table_compay)
  for row in cursor.fetchall():
     print(row)

# %%
select_fetch_nepse_id ='select nepse_company_id From company'
with connection.cursor() as cursor:
  cursor.execute(select_fetch_nepse_id)
  for row in cursor.fetchall():
     print(row)

# %%
for key in d.keys():
    a = key
    print(a)
# Out:
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 151
# 152
# 153
# 154
# 155
# 156
# 158
# 159
# 160
# 163
# 164
# 166
# 171
# 172
# 174
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 192
# 194
# 195
# 198
# 200
# 201
# 203
# 204
# 205
# 207
# 209
# 210
# 211
# 213
# 215
# 217
# 219
# 221
# 222
# 226
# 227
# 228
# 230
# 231
# 232
# 233
# 235
# 236
# 238
# 242
# 244
# 245
# 249
# 250
# 255
# 256
# 259
# 261
# 263
# 268
# 273
# 274
# 277
# 280
# 281
# 282
# 283
# 286
# 288
# 289
# 291
# 292
# 296
# 298
# 299
# 307
# 309
# 311
# 312
# 313
# 314
# 315
# 319
# 327
# 330
# 338
# 339
# 341
# 346
# 347
# 348
# 350
# 352
# 354
# 355
# 357
# 358
# 359
# 360
# 361
# 362
# 371
# 380
# 385
# 387
# 390
# 391
# 393
# 396
# 397
# 398
# 400
# 401
# 403
# 417
# 418
# 419
# 420
# 421
# 427
# 428
# 440
# 441
# 447
# 449
# 450
# 451
# 456
# 459
# 469
# 471
# 472
# 473
# 474
# 479
# 487
# 488
# 490
# ...

# %%
from sqlalchemy import create_engine
df = pd.DataFrame.from_dict(d)
engine = create_engine('mysql+pymysql://user:passwd@host:port/name').connect()
df.to_sql('ohlc', con=engine, if_exists='replace')

# %%
df[for i in 0].values

# %%
inserting_ohlc_values ='''INSERT INTO OHLC(company_id) VALUES(%s); '''
record_to_insert=[(key)]
with connection.cursor() as cursor:
    cursor.execute(inserting_ohlc_values, record_to_insert)
    connection.commit()

# %%
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
