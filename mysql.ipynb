# %%
import mysql.connector
from mysql.connector import Error

# %%
try:
    DataBase = mysql.connector.connect(host ="localhost", 
                                        user = "root",
                                        password = "Manandhar123$",
                                        database ="nepsepedia")

    if DataBase.is_connected():
        db_info = DataBase.get_server_info()
        print("My sql is conncected", db_info)
        cursor = DataBase.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("Record is executed", record)

except Error as e:
    print("Error is happening", e)
    
finally:
    if DataBase.is_connected():
       # cursor.close()
       # connection.close()
        print("Mysql is connected")

# %%
create_table_company ='''
CREATE TABLE Company(
  id int(11) NOT NULL,
  nepse_company_id int(11) NOT NULL,
  company_name varchar(255) DEFAULT NULL,
  company_code varchar(255) DEFAULT NULL,
  sector_id int(11) DEFAULT NULL,
  status varchar(6) DEFAULT NULL,
  classes varchar(255) DEFAULT NULL,
  instrument varchar(255) DEFAULT NULL,
  corporate_email varchar(255) DEFAULT NULL,
  website varchar(255) DEFAULT NULL,
  created_at timestamp NULL DEFAULT NULL,
  updated_at timestamp NULL DEFAULT NULL
)ENGINE=InnoDB DEFAULT CHARSET=utf8;'''
with DataBase.cursor() as cursor:
    cursor.execute(create_table_company)
    DataBase.commit()

# %%
create_table_sector ='''
CREATE TABLE sector (
  id int(11) NOT NULL,
  sector_name varchar(255) DEFAULT NULL,
  sector_code varchar(255) DEFAULT NULL,
  created_at datetime DEFAULT CURRENT_TIMESTAMP,
  updated_at datetime DEFAULT CURRENT_TIMESTAMP
) ENGINE=InnoDB DEFAULT CHARSET=utf8;'''

with DataBase.cursor() as cursor:
    cursor.execute(create_table_sector)
    DataBase.commit()

# %%
create_table_ohlc ='''
CREATE TABLE `ohlc` (
  id int(11) NOT NULL,
  company_id int(11) DEFAULT NULL,
  open float DEFAULT NULL,
  high float DEFAULT NULL,
  low float DEFAULT NULL,
  close float DEFAULT NULL,
  adj_close float DEFAULT NULL,
  volume int(11) DEFAULT NULL,
  created_at datetime DEFAULT NULL,
  updated_at datetime DEFAULT NULL
) ENGINE=InnoDB DEFAULT CHARSET=utf8;
'''
with DataBase.cursor() as cursor:
    cursor.execute(create_table_ohlc)
    DataBase.commit()

# %%
insert_sector_data ='''
INSERT INTO sector (id, sector_name, sector_code, created_at, updated_at) VALUES
(1, 'Commercial Banks', 'COMMBANK', NULL, NULL),
(2, 'Corporate Debenture', 'CORDEB', NULL, NULL),
(3, 'Development Banks', 'DEVBANK', NULL, NULL),
(4, 'Finance', 'FINANCE', NULL, NULL),
(5, 'Hotels And Tourism', 'HOTELS', NULL, NULL),
(6, 'Hydro Power', 'HYDRO', NULL, NULL),
(7, 'Investment', 'INVSTMNT', NULL, NULL),
(8, 'Life Insurance', 'LIFE', NULL, NULL),
(9, 'Manufacturing And Processing', 'MANU', NULL, NULL),
(10, 'Microfinance', 'MICROF', NULL, NULL),
(11, 'Mutual Fund', 'MF', NULL, NULL),
(12, 'Non Life Insurance', 'NONLIFE', NULL, NULL),
(13, 'Others', 'OTHERS', NULL, NULL),
(14, 'Preference Share', 'PREFSHARES', NULL, NULL),
(15, 'Promoter Share', 'PROMOSHARES', NULL, NULL),
(16, 'Tradings', 'TRADINGS', NULL, NULL);
'''
with DataBase.cursor() as cursor:
    cursor.execute(insert_sector_data)
    DataBase.commit()

# %%
insert_company_data = '''
INSERT INTO Company (id, nepse_company_id, company_name, company_code, sector_id, status, classes, instrument, corporate_email, website, created_at, updated_at ) VALUES
(1, 131, 'Nabil Bank Limited', 'NABIL', 1, 'Active', '', 'Equity', 'prakash.basukala@nabilbank.com', '', NULL, NULL),
(2, 133, 'Standard Chartered Bank Limited', 'SCB', 1, 'Active', '', 'Equity', 'Legal.Nepal@sc.com', '', NULL, NULL),
(3, 135, 'Nepal SBI Bank Limited', 'SBI', 1, 'Active', '', 'Equity', 'law@nsbl.com.np', '', NULL, NULL),
(4, 136, 'Nepal Bangladesh Bank Limited', 'NBB', 1, 'Active', '', 'Equity', 'bishwapoudel@nbbl.com.np', '', NULL, NULL),
(5, 137, 'Everest Bank Limited', 'EBL', 1, 'Active', '', 'Equity', 'suresh.chapagain@ebl.com.np', '', NULL, NULL),
(6, 138, 'Bank of Kathmandu Ltd.', 'BOKL', 1, 'Active', '', 'Equity', 'deepak.gautam@bok.com.np', '', NULL, NULL),
(7, 139, 'NIC Asia Bank Ltd.', 'NICA', 1, 'Active', '', 'Equity', 'suraj.shrestha3508@nicasiabank.com', '', NULL, NULL),
(8, 140, 'Machhapuchhre Bank Limited', 'MBL', 1, 'Active', '', 'Equity', 'Tika.Bhattarai@mbl.com.np', 'http://www.machbank.com', NULL, NULL),
(9, 141, 'Laxmi Bank Limited', 'LBL', 1, 'Active', '', 'Equity', 'piyush.aryal@laxmibank.com', '', NULL, NULL),
(10, 142, 'Kumari Bank Limited', 'KBL', 1, 'Active', '', 'Equity', 'info@kumaribank.com', 'http://www.kumaribank.com', NULL, NULL),
(11, 144, 'Nepal Credit And Commercial Bank Limited', 'NCCB', 1, 'Active', '', 'Equity', 'corporate@nccbank.com.np', 'http://www.nccbank.com.np', NULL, NULL),
(12, 145, 'Siddhartha Bank Limited', 'SBL', 1, 'Active', '', 'Equity', 'laxman.ghimire@sbl.com.np', '', NULL, NULL),
(13, 147, 'Soaltee Hotel Limited', 'SHL', 5, 'Active', '', 'Equity', 'lbkhatri@soaltee.com.np', '', NULL, NULL),
(14, 148, 'Taragaon Regency Hotel Limited', 'TRH', 5, 'Active', '', 'Equity', 'info@taragaon.com', '', NULL, NULL),
(15, 149, 'Oriental Hotels Limited', 'OHL', 5, 'Active', '', 'Equity', 'legal@radkat.com.np', '', NULL, NULL),
(16, 152, 'National Hydro Power Company Limited', 'NHPC', 6, 'Active', '', 'Equity', 'nhpc@nhpc.com', '', NULL, NULL),
(17, 153, 'Butwal Power Company Limited', 'BPCL', 6, 'Active', '', 'Equity', 'hari.budhathoki@bpc.com.np', 'http://www.bpc.com.np', NULL, NULL),
(18, 154, 'Chilime Hydropower Company Limited', 'CHCL', 6, 'Active', '', 'Equity', 'narayanprasad.acharya@chilime.com.np', '', NULL, NULL),
(19, 155, 'Salt Trading Corporation', 'STC', 16, 'Active', '', 'Equity', 'legalstcnepal@gmail.com', '', NULL, NULL),
(20, 156, 'Bishal Bazar Company Limited', 'BBC', 16, 'Active', '', 'Equity', 'info@bishalbazar.com.np', '', NULL, NULL),
(21, 163, 'Nirdhan Utthan Laghubitta Bittiya Sanstha Limited', 'NUBL', 10, 'Active', '', 'Equity', 'info@nirdhan.com', '', NULL, NULL),
(22, 164, 'Chhimek Laghubitta Bikas Bank Limited', 'CBBL', 10, 'Active', '', 'Equity', 'info@chhimekbank.org', '', NULL, NULL),
(23, 166, 'Deprosc Laghubitta Bittiya Sanstha Limited', 'DDBL', 10, 'Active', '', 'Equity', 'gyanendra.aryal@ddbank.org.np', '', NULL, NULL),
(24, 171, 'Sanima Bank Limited', 'SANIMA', 1, 'Active', '', 'Equity', 'RUDRA@sanimabank.com', '', NULL, NULL),
(25, 172, 'Narayani Development Bank Limited', 'NABBC', 3, 'Active', '', 'Equity', 'info@ndbl.com.np', '', NULL, NULL),
(26, 176, 'Nepal Insurance Co. Ltd.', 'NICL', 12, 'Active', '', 'Equity', 'legal@nepalinsurance.com.np', '', NULL, NULL),
(27, 177, 'Rastriya Beema Company Limited', 'RBCL', 12, 'Active', '', 'Equity', 'niranjan.acharya@rbcl.gov.np', '', NULL, NULL),
(28, 178, 'National Life Insurance Co. Ltd.', 'NLICL', 8, 'Active', '', 'Equity', 'it@nationallife.com.np', '', NULL, NULL),
(29, 179, 'Himalayan General Insurance Co. Ltd', 'HGI', 12, 'Active', '', 'Equity', 'dhruba@hgi.com.np', '', NULL, NULL),
(30, 180, 'United Insurance Co. (Nepal) Ltd.', 'UIC', 12, 'Active', '', 'Equity', 'bidur@unitedinsurance.com.np', '', NULL, NULL),
(31, 181, 'Everest Insurance Co. Ltd.', 'EIC', 12, 'Active', '', 'Equity', 'pradip@eic.com.np', '', NULL, NULL),
(32, 182, 'Premier Insurance Co. Ltd.', 'PIC', 12, 'Active', '', 'Equity', 'premier@picl.com.np', '', NULL, NULL),
(33, 183, 'Neco Insurance Co. Ltd.', 'NIL', 12, 'Active', '', 'Equity', 'bishnu@neco.com.np', 'http://www.necoinsurance.com.np', NULL, NULL),
(34, 184, 'Prabhu Insurance Ltd.', 'PRIN', 12, 'Active', '', 'Equity', 'info@prabhuinsurance.com', 'http://www.prabhuinsurance.com', NULL, NULL),
(35, 185, 'Sagarmatha Insurance Co. Ltd.', 'SIC', 12, 'Active', '', 'Equity', 'bishow.ad@sagarmathainsurance.com.np', '', NULL, NULL),
(36, 186, 'IME General Insurance Ltd.', 'IGI', 12, 'Active', '', 'Equity', 'sharan.regmi@iginepal.com', 'http://www.iginepal.com', NULL, NULL),
(37, 187, 'Nepal Life Insurance Co. Ltd.', 'NLIC', 8, 'Active', '', 'Equity', 'info@nepallife.com.np', '', NULL, NULL),
(38, 188, 'Life Insurance Co. Nepal', 'LICN', 8, 'Active', '', 'Equity', 'binod.bhujel@licnepal.com.np', 'http://www.licnepal.com.np', NULL, NULL),
(39, 189, 'Prudential Insurance Co. Ltd.', 'PICL', 12, 'Active', '', 'Equity', 'anand.khadka@prudential.com.np', 'http://www.prudential.com.np', NULL, NULL),
(40, 190, 'Lumbini General Insurance Co. Ltd.', 'LGIL', 12, 'Active', '', 'Equity', 'devendra@lgic.com.np', '', NULL, NULL),
(41, 192, 'Shikhar Insurance Co. Ltd.', 'SICL', 12, 'Active', '', 'Equity', 'suraj@shikharinsurance.com', 'http://www.shikharinsurance.com', NULL, NULL),
(42, 194, 'Nepal Finance Ltd.', 'NFS', 4, 'Active', '', 'Equity', 'mail@nefinsco.com', '', NULL, NULL),
(43, 195, 'Bottlers Nepal (Balaju) Limited', 'BNL', 9, 'Active', '', 'Equity', 'prburma@coca-cola.com.np', '', NULL, NULL),
(44, 198, 'Nepal Lube Oil Limited', 'NLO', 9, 'Active', '', 'Equity', 'g.bhattarai@cg.holdings', '', NULL, NULL),
(45, 204, 'Gurkhas Finance Ltd.', 'GUFL', 4, 'Active', '', 'Equity', 'mukunda@gurkhasfinance.com.np', '', NULL, NULL),
(46, 210, 'Citizen Investment Trust', 'CIT', 7, 'Active', '', 'Equity', 'cit.cmkt@gmail.com', '', NULL, NULL),
(47, 213, 'Bottlers Nepal (Terai) Limited', 'BNT', 9, 'Active', '', 'Equity', 'prburma@coca-cola.com.np', '', NULL, NULL),
(48, 219, 'Unilever Nepal Limited', 'UNL', 9, 'Active', '', 'Equity', 'sonam.shrestha@unilever.com', '', NULL, NULL),
(49, 227, 'Best Finance Company Ltd.', 'BFC', 4, 'Active', '', 'Equity', 'raj.shrestha@bestfinance.com.np', '', NULL, NULL),
(50, 232, 'Goodwill Finance Co. Ltd.', 'GFCL', 4, 'Active', '', 'Equity', 'gfcl@gfcl.com', '', NULL, NULL),
(51, 235, 'Himalayan Distillery Limited', 'HDL', 9, 'Active', '', 'Equity', 'netra.timsina@jginepal.com', '', NULL, NULL),
(52, 236, 'Pokhara Finance Ltd.', 'PFL', 4, 'Active', '', 'Equity', 'buddhilaxmi.gurung@pokharafinance.com.np', '', NULL, NULL),
(53, 238, 'NMB Bank Limited', 'NMB', 1, 'Active', '', 'Equity', 'pramod.dahal@nmb.com.np', 'http://www.nmb.com.np', NULL, NULL),
(54, 244, 'Shree Investment Finance Co. Ltd.', 'SIFC', 4, 'Active', '', 'Equity', 'info@shreefinance.com.np', 'http://www.shreefinance.com.np', NULL, NULL),
(55, 245, 'Central Finance Co. Ltd.', 'CFCL', 4, 'Active', '', 'Equity', 'ashok@centralfinance.com.np', '', NULL, NULL),
(56, 250, 'Janaki Finance Ltd.', 'JFL', 4, 'Active', '', 'Equity', 'janakifinancecompany@yahoo.com', '', NULL, NULL),
(57, 255, 'Prabhu Bank Limited', 'PRVU', 1, 'Active', '', 'Equity', 'amit.bhandari@prabhubank.com', '', NULL, NULL),
(58, 256, 'Samriddhi Finance Company Limited', 'SFCL', 4, 'Active', '', 'Equity', 'cs@sfcl.com.np', 'http://www.wmerchantbank.com', NULL, NULL),
(59, 263, 'Guheshowori Merchant Bank & Finance Co. Ltd.', 'GMFIL', 4, 'Active', '', 'Equity', 'dipesh.shakya@gmbf.com.np', '', NULL, NULL),
(60, 268, 'Swabalamban Laghubitta Bittiya Sanstha Limited', 'SWBBL', 10, 'Active', '', 'Equity', 'dr.shakya@swbbl.com.np', '', NULL, NULL),
(61, 273, 'ICFC Finance Limited', 'ICFC', 4, 'Active', '', 'Equity', 'sunil.pant@icfcbank.com', 'http://www.icfcbank.com', NULL, NULL),
(62, 274, 'Excel Development Bank Ltd.', 'EDBL', 3, 'Active', '', 'Equity', 'info@edb.com.np', '', NULL, NULL),
(63, 277, 'Everest Bank Limited Con. Pref.', 'EBLCP', 1, 'Active', '', 'Preference Shares', 'suresh.chapagain@ebl.com.np', '', NULL, NULL),
(64, 280, 'Siddhartha Insurance Ltd.', 'SIL', 12, 'Active', '', 'Equity', 'info@siddharthainsurance.com', '', NULL, NULL),
(65, 307, 'Nepal Doorsanchar Comapany Limited', 'NTC', 13, 'Active', '', 'Equity', 'cs.nt@ntc.net.np', 'http://www.ntc.net.np', NULL, NULL),
(66, 338, 'ProgressiveFinance Limited', 'PROFL', 4, 'Active', '', 'Equity', 'bishal@pfltd.com.np', 'http://www.pfltd.com.np', NULL, NULL),
(67, 341, 'Global IME Bank Limited', 'GBIME', 1, 'Active', '', 'Equity', 'bishnu.baskota@gibl.com.np', 'http://www.globalimebank.com', NULL, NULL),
(68, 348, 'Citizen Bank International Limited', 'CZBIL', 1, 'Active', '', 'Equity', 'rajendra.shrestha@ctznbank.com', '', NULL, NULL),
(69, 357, 'Prime Commercial Bank Ltd.', 'PCBL', 1, 'Active', '', 'Equity', 'santosh.baral@pcbl.com.np', '', NULL, NULL),
(70, 358, 'Lumbini Bikas Bank Ltd.', 'LBBL', 3, 'Active', '', 'Equity', 'hari.subedi@lumbinibikasbank.com', '', NULL, NULL),
(71, 359, 'Sunrise Bank Limited', 'SRBL', 1, 'Active', '', 'Equity', 'ishwar.pathak@sunrisebank.com.np', '', NULL, NULL),
(72, 360, 'Arun Valley Hydropower Development Co. Ltd.', 'AHPC', 6, 'Active', '', 'Equity', 'arunvalley2054@gmail.com', '', NULL, NULL),
(73, 371, 'Miteri Development Bank Limited', 'MDB', 3, 'Active', '', 'Equity', 'ramesh@miteribank.com.np', 'http://www.miteribank.com.np', NULL, NULL),
(74, 385, 'Asian Life Insurance Co. Limited', 'ALICL', 8, 'Active', '', 'Equity', 'murariraj.humagain@asianlife.com.np', '', NULL, NULL),
(75, 393, 'Prime Life Insurance Company Limited', 'PLIC', 8, 'Active', '', 'Equity', 'rajan@primelifenepal.com', '', NULL, NULL),
(76, 396, 'Nerude Laghubita Bikas Bank Limited', 'NLBBL', 10, 'Active', '', 'Equity', 'nerudeprasasan@gmail.com', '', NULL, NULL),
(77, 397, 'Agriculture Development Bank Limited', 'ADBL', 1, 'Active', '', 'Equity', 'cs@adbl.gov.np', '', NULL, NULL),
(78, 401, 'Mahalaxmi Bikas Bank Ltd.', 'MLBL', 3, 'Active', '', 'Equity', 'som.pant@mahalaxmi.com.np', 'http://www.yetibank.com', NULL, NULL),
(79, 403, 'Surya Life Insurance Company Limited', 'SLICL', 8, 'Active', '', 'Equity', 'raju.rajchal@suryalife.com', '', NULL, NULL),
(80, 417, 'Garima Bikas Bank Limited', 'GBBL', 3, 'Active', '', 'Equity', 'info@garimabank.com.np', '', NULL, NULL),
(81, 418, 'Jyoti Bikas Bank Limited', 'JBBL', 3, 'Active', '', 'Equity', 'krishna.oasti@jbbl.com.np', '', NULL, NULL),
(82, 428, 'Karnali Development Bank Limited', 'KRBL', 3, 'Active', '', 'Equity', 'sniraaz@kdblnepal.com', '', NULL, NULL),
(83, 447, 'Gurans Life Insurance Company Ltd.', 'GLICL', 8, 'Active', '', 'Equity', 'balmukunda@guranslife.com', '', NULL, NULL),
(84, 450, 'Corporate Development Bank Limited', 'CORBL', 3, 'Active', '', 'Equity', 'info@corporatebank.com.np', '', NULL, NULL),
(85, 459, 'Kamana Sewa Bikas Bank Limited', 'KSBBL', 3, 'Active', '', 'Equity', 'hari.lamsal@kamanasewabank.com', '', NULL, NULL),
(86, 471, 'Multipurpose Finance Company Limited', 'MPFL', 4, 'Active', '', 'Equity', 'jha555p@gmail.com', '', NULL, NULL),
(87, 472, 'Shangrila Development Bank Ltd.', 'SADBL', 3, 'Active', '', 'Equity', 'info@shangrilabank.com', '', NULL, NULL),
(88, 473, 'Shine Resunga Development Bank Ltd.', 'SHINE', 3, 'Active', '', 'Equity', 'info@srdb.com.np', '', NULL, NULL),
(89, 474, 'Muktinath Bikas Bank Ltd.', 'MNBBL', 3, 'Active', '', 'Equity', 'info@muktinathbank.com.np', '', NULL, NULL),
(90, 490, 'First Micro Finance Development Bank Ltd.', 'FMDBL', 10, 'Active', '', 'Equity', 'danaraj@fmdb.com.np', '', NULL, NULL),
(91, 502, 'Summit Laghubitta Bittiya Sanstha Limited', 'SMFDB', 10, 'Active', '', 'Equity', 'banksummit@yahoo.com', '', NULL, NULL),
(92, 516, 'Manjushree Finance Ltd.', 'MFIL', 4, 'Active', '', 'Equity', 'info@manjushreefinance.com.np', '', NULL, NULL),
(93, 517, 'Nepal Bank Limited', 'NBL', 1, 'Active', '', 'Equity', 'suresh.ghimire@nbl.com.np', '', NULL, NULL),
(94, 532, 'Civil Bank Ltd', 'CBL', 1, 'Active', '', 'Equity', 'hirakaji.basnet@civilbank.com.np', '', NULL, NULL),
(95, 545, 'Swarojgar Laghu Bitta Bikas Bank Ltd.', 'SLBBL', 10, 'Active', '', 'Equity', 'info@slbbl.com', '', NULL, NULL),
(96, 559, 'NLG Insurance Company Ltd.', 'NLG', 12, 'Active', '', 'Equity', 'manoj.shrestha@nlgi.com.np', '', NULL, NULL),
(97, 561, 'Sindhu Bikash Bank Ltd', 'SINDU', 3, 'Active', '', 'Equity', 'info@sindhubank.com.np', '', NULL, NULL),
(98, 562, 'Mega Bank Nepal Ltd.', 'MEGA', 1, 'Active', '', 'Equity', 'tulsi.pokharel@megabank.com.np', '', NULL, NULL),
(99, 574, 'Sana Kisan Bikas Bank Ltd', 'SKBBL', 10, 'Active', '', 'Equity', 'info@skbbl.com.np', 'http://www.skbbl.com.np', NULL, NULL),
(100, 575, 'RMDC Laghubitta Bittiya Sanstha Ltd.', 'RMDC', 10, 'Active', '', 'Equity', 'rmdc@wlink.com.np', 'http://www.rmdcnepalc.com', NULL, NULL),
(101, 583, 'Grameen Bikas Laghubitta Bittiya Sanstha Ltd.', 'GBLBS', 10, 'Active', '', 'Equity', 'info@grameenbanknepal.com', 'http://www.grameenbanknepal.com', NULL, NULL),
(102, 587, 'Reliance Finance Ltd.', 'RLFL', 4, 'Active', '', 'Equity', 'samaj@reliancenepal.com.np', '', NULL, NULL),
(103, 591, 'Sanima Mai Hydropower Ltd.', 'SHPC', 6, 'Active', '', 'Equity', 'jayanta@sanimahydro.com', '', NULL, NULL),
(104, 592, 'Naya Sarathi Laghubitta Bittiya Sanstha Limited', 'NSLB', 10, 'Active', '', 'Equity', 'nimdilen@gmail.com', '', NULL, NULL),
(105, 593, 'Kalika Microcredit Development Bank Ltd.', 'KMCDB', 10, 'Active', '', 'Equity', 'info@kalikabank.com.np', '', NULL, NULL),
(106, 601, 'Mithila LaghuBitta Bittiya Sanstha Limited', 'MLBBL', 10, 'Active', '', 'Equity', 'mlboperationdepart@gmail.com', 'http://www.mldbank.com.np', NULL, NULL),
(107, 605, 'Century Commercial Bank Ltd.', 'CCBL', 1, 'Active', '', 'Equity', 'Tulsi.Bhattarai@centurybank.com.np', '', NULL, NULL),
(108, 610, 'Ridi Hydropower Development Company Ltd.', 'RHPC', 6, 'Active', '', 'Equity', 'alok.kc4@gmail.com', '', NULL, NULL),
(109, 618, 'Laxmi Laghubitta Bittiya Sanstha Ltd.', 'LLBS', 10, 'Active', '', 'Equity', 'prakash.sharma@laxmilaghu.com.np', '', NULL, NULL),
(110, 636, 'NIBL Samriddhi Fund 1', 'NIBSF1', 1, 'Active', '', 'Mutual Funds', 'deepa@nibl.com.np', 'http://www.nibl.com.np', NULL, NULL),
(111, 682, 'Mirmire Microfinance Development Bank Ltd.', 'MMFDB', 10, 'Active', '', 'Equity', 'info@mirmirebank.com.np', 'http://www.mirmirebank.com.np', NULL, NULL),
(112, 686, 'Barun Hydropower Co. Ltd.', 'BARUN', 6, 'Active', '', 'Equity', 'barunhydro@gmail.com', '', NULL, NULL),
(113, 687, 'Vijaya laghubitta Bittiya Sanstha Ltd.', 'VLBS', 10, 'Active', '', 'Equity', 'nsapkota@vlbs.com.np', '', NULL, NULL),
(114, 693, 'Civil Laghubitta Bittiya Sanstha Ltd.', 'CLBSL', 10, 'Active', '', 'Equity', 'binod.acharya@civillaghubitta.com.np', 'http://www.ilfcomicro.com.np', NULL, NULL),
(115, 694, 'Kisan Lagubitta Bittiya Sanstha Limited', 'KLBSL', 10, 'Active', '', 'Equity', 'nrnmfiho@gmail.com', '', NULL, NULL),
(116, 695, 'Janautthan Samudayic Laghubitta Bikas Bank Ltd.', 'JSLBB', 10, 'Active', '', 'Equity', 'info@jucbank.com.np', '', NULL, NULL),
(117, 697, 'Api Power Company Ltd.', 'API', 6, 'Active', '', 'Equity', 'srijanadangal@gmail.com', '', NULL, NULL),
(118, 704, 'NMB Microfinance Bittiya Sanstha Ltd.', 'NMBMF', 10, 'Active', '', 'Equity', 'govinda.banstola@nmbmicrofinance.com', 'http://www.cleanvillage.com.np', NULL, NULL),
(119, 705, 'Global IME Laghubitta Bittiya Sanstha Ltd.', 'GILB', 10, 'Active', '', 'Equity', 'kiran.rmfi@gmail.com', 'http://www.reliablebank.com.np', NULL, NULL),
(120, 1740, 'Global IME Samunnat Scheme-1', 'GIMES1', 1, 'Active', '', 'Mutual Funds', 'bishnu.baskota@gibl.com.np', 'http://www.globalimebank.com', NULL, NULL),
(121, 1741, 'Mero Microfinance Bittiya Sanstha Ltd.', 'MERO', 10, 'Active', '', 'Equity', 'meromicrofinance@gmail.com', '', NULL, NULL),
(122, 2742, 'Hydorelectricity Investment and Development Company Ltd', 'HIDCL', 7, 'Active', '', 'Equity', 'hidcl1300@gmail.com', '', NULL, NULL),
(123, 2743, 'Ngadi Group Power Ltd.', 'NGPL', 6, 'Active', '', 'Equity', 'nyadigroup06@gmail.com', '', NULL, NULL),
(124, 2744, 'Green Development Bank Ltd.', 'GRDBL', 3, 'Active', '', 'Equity', 'info@greenbank.com.np', '', NULL, NULL),
(125, 2746, 'National Microfinance Bittiya Sanstha Ltd.', 'NMFBS', 10, 'Active', '', 'Equity', 'nationalrcrupakheti@gmail.com', 'http://www.nationalmicrofinance.com.np', NULL, NULL),
(126, 2748, 'RSDC Laghubitta Bittiya Sanstha Ltd.', 'RSDC', 10, 'Active', '', 'Equity', 'info@rsdcmf.com', '', NULL, NULL),
(127, 2751, 'Khanikhola Hydropower Co. Ltd.', 'KKHC', 6, 'Active', '', 'Equity', 'khanikhola.hpc@gmail.com', '', NULL, NULL),
(128, 2752, 'NMB Hybrid Fund L-1', 'NMBHF1', 1, 'Active', '', 'Mutual Funds', 'pramod.dahal@nmb.com.np', 'http://www.nmb.com.np', NULL, NULL),
(129, 2753, 'Nabil Equity Fund', 'NEF', 1, 'Active', '', 'Mutual Funds', 'prakash.basukala@nabilbank.com', '', NULL, NULL),
(130, 2754, 'Dibyashwori Hydropower Ltd.', 'DHPL', 6, 'Active', '', 'Equity', 'dibyashwarihydropower@gmail.com', '', NULL, NULL),
(131, 2755, 'NIBL Pragati Fund', 'NIBLPF', 1, 'Active', '', 'Mutual Funds', 'deepa@nibl.com.np', 'http://www.nibl.com.np', NULL, NULL),
(132, 2757, 'Arun Kabeli Power Ltd.', 'AKPL', 6, 'Active', '', 'Equity', 'info@arunkabeli.com', '', NULL, NULL),
(133, 2758, 'Forward Microfinance Bittiya Sanstha Ltd.', 'FOWAD', 10, 'Active', '', 'Equity', 'krishna@forward.org.np', '', NULL, NULL),
(134, 2759, 'Synergy Power Development Ltd.', 'SPDL', 6, 'Active', '', 'Equity', 'synergy@gmail.com', '', NULL, NULL),
(135, 2760, 'United Modi Hydropower Ltd.', 'UMHL', 6, 'Active', '', 'Equity', 'navaraj.advocate@gmail.com', '', NULL, NULL),
(136, 2761, 'Samata Gharelu Laghubitta Bittiya Sanstha Limited', 'SMATA', 10, 'Active', '', 'Equity', 'samata@samata.org.np', '', NULL, NULL),
(137, 2765, 'Laxmi Equity Fund', 'LEMF', 1, 'Active', '', 'Mutual Funds', 'piyush.aryal@laxmibank.com', '', NULL, NULL),
(138, 2766, 'Chhyangdi Hydropower Ltd.', 'CHL', 6, 'Active', '', 'Equity', 'info@chpl.com.np', '', NULL, NULL),
(139, 2767, 'Himalayan Power Partner Ltd.', 'HPPL', 6, 'Active', '', 'Equity', 'hpphydro.binaya@gmail.com', 'http://www.hpp.com.np', NULL, NULL),
(140, 2768, 'Mahuli Samudayik Laghubitta Bittiya Sanstha Ltd.', 'MSLB', 10, 'Active', '', 'Equity', 'saroj.singh@mslbsl.com.np', '', NULL, NULL),
(141, 2769, 'Nepal Hydro Developers Ltd.', 'NHDL', 6, 'Active', '', 'Equity', 'info@charnawathihydro.com', '', NULL, NULL),
(142, 2770, 'Siddhartha Equity Fund', 'SEF', 1, 'Active', '', 'Mutual Funds', 'laxman.ghimire@sbl.com.np', '', NULL, NULL),
(143, 2771, 'Support Microfinance Bittiya Sanstha Ltd.', 'SMB', 10, 'Active', '', 'Equity', 'smicrofinance@gmail.com', '', NULL, NULL),
(144, 2773, 'Sanima Equity Fund', 'SAEF', 1, 'Active', '', 'Mutual Funds', 'RUDRA@sanimabank.com', '', NULL, NULL),
(145, 2774, 'Unnati Sahakarya Laghubitta Bittiya Sanstha Limited', 'USLB', 10, 'Active', '', 'Equity', 'prem.pathak@unnatimfi.com.np', 'http://www.unnatimfi.com.np', NULL, NULL),
(146, 2776, 'Radhi Bidyut Company Ltd', 'RADHI', 6, 'Active', '', 'Equity', 'info@radhibidyut.com.np', '', NULL, NULL),
(147, 2779, 'NIC Asia Growth Fund', 'NICGF', 1, 'Active', '', 'Mutual Funds', 'suraj.shrestha3508@nicasiabank.com', '', NULL, NULL),
(148, 2780, 'Citizens Mutual Fund -1', 'CMF1', 1, 'Active', '', 'Mutual Funds', 'rajendra.shrestha@ctznbank.com', '', NULL, NULL),
(149, 2783, 'Rairang Hydropower Development Company Ltd.', 'RRHP', 6, 'Active', '', 'Equity', 'sayikanepal@gmail.com', 'http://www.ridihydro.com.np', NULL, NULL),
(150, 2786, 'Panchakanya Mai Hydropower Ltd', 'PMHPL', 6, 'Active', '', 'Equity', 'panchakanyamai@gmail.com', '', NULL, NULL),
(151, 2787, 'Kalika power Company Ltd', 'KPCL', 6, 'Active', '', 'Equity', 'prabinthapaliya143@gmail.com', '', NULL, NULL),
(152, 2788, 'Ankhu Khola Jalvidhyut Company Ltd', 'AKJCL', 6, 'Active', '', 'Equity', 'info@aankhukholahydro.com.np', 'www.aankhukholahydropower.com.np', NULL, NULL),
(153, 2789, 'Joshi Hydropower Development Company Ltd', 'JOSHI', 6, 'Active', '', 'Equity', 'info@joshihydropower.com', 'www.joshihydropower.com', NULL, NULL),
(154, 2790, 'Aarambha Chautari Laghubitta Bittiya Sanstha Limited', 'ACLBSL', 10, 'Active', '', 'Equity', 'ceo.aarambhachautari@gmail.com', 'www.chautarimfb.com', NULL, NULL),
(155, 2792, 'Upper Tamakoshi Hydropower Ltd', 'UPPER', 6, 'Active', '', 'Equity', 'neautp@mos.com.np', 'www.tamakhosihydro.org.np', NULL, NULL),
(156, 2804, 'Samudayik Laghubitta Bittiya Sanstha Limited', 'SLBSL', 10, 'Active', '', 'Equity', 'samudayikbank@gmail.com', 'www.samudayikbank.com.np', NULL, NULL),
(157, 2806, 'Ghalemdi Hydro Limited', 'GHL', 6, 'Active', '', 'Equity', 'relinarenergy@gmail.com', 'www.ghalemdihydro.com', NULL, NULL),
(158, 2807, 'Asha Laghubitta Bittiya Sanstha Ltd', 'ALBSL', 10, 'Active', '', 'Equity', 'ashamicrofinance@gmail.com', 'www.ashamicrofinance.com.np', NULL, NULL),
(159, 2809, 'SHIVAM CEMENTS LTD', 'SHIVM', 9, 'Active', '', 'Equity', 'info@shivamcement.com', 'www.shivamcement.com', NULL, NULL),
(160, 2810, 'UNIVERSAL POWER COMPANY LTD', 'UPCL', 6, 'Active', '', 'Equity', 'universal2067@gmail.com', 'www.universalpowercompany.com.np', NULL, NULL),
(161, 2811, 'Mountain Hydro Nepal Limited', 'MHNL', 6, 'Active', '', 'Equity', 'mountainhydronepal@gmail.com', 'www.mountainhydronepal.com.np', NULL, NULL),
(162, 2813, 'Panchthar Power Compant Limited', 'PPCL', 6, 'Active', '', 'Equity', 'ppchewa@gmail.com', 'www.ppcl.com.np', NULL, NULL),
(163, 2815, 'Ganapati Laghubitta Bittiya Sanstha Limited', 'GMFBS', 10, 'Active', '', 'Equity', 'info@ganapatimicro.com.np', 'www.ganapatimicro.com.np', NULL, NULL),
(164, 2824, 'Himalaya Urja Bikas Company Limited', 'HURJA', 6, 'Active', '', 'Equity', 'himalayaurja@gmail.com', 'www.himalurja.com', NULL, NULL),
(165, 2825, '10% NIC Asia Debenture 2085/86', 'NICAD 85/86', 1, 'Active', '', 'Non-Convertible Debentures', 'suraj.shrestha3508@nicasiabank.com', '', NULL, NULL),
(166, 2826, 'Gurans Laghubitta Bittiya Sanstha Limited', 'GLBSL', 10, 'Active', '', 'Equity', 'mishranagendra2015@gmail.com', 'www.guranslaghubitta.com.np', NULL, NULL),
(167, 2828, '10% Sanima Bank Limited Debenture', 'SAND2085', 1, 'Active', '', 'Non-Convertible Debentures', 'RUDRA@sanimabank.com', '', NULL, NULL),
(168, 2829, 'Swabhimaan Laghubitta Bittiya Sanstha Limited', 'SMFBS', 10, 'Active', '', 'Equity', 'swabhimaansmbsl@gmail.com', 'www.swabhimaanmicrofinance.com', NULL, NULL),
(169, 2831, 'Union Hydropower Limited', 'UNHPL', 6, 'Active', '', 'Equity', 'unionhppl@gmail.com', 'www.unionhydropower.com.np', NULL, NULL),
(170, 2832, 'Infinity Laghubitta Bittiya Sanstha Limited', 'ILBS', 10, 'Active', '', 'Equity', 'ilbslfinance@gmail.com', 'www.infinitymbsl.com', NULL, NULL),
(171, 2834, '10% Sunrise Debenture 2080', 'SRD80', 1, 'Active', '', 'Non-Convertible Debentures', 'ishwar.pathak@sunrisebank.com.np', '', NULL, NULL),
(172, 2835, 'NABIL BALANCED FUND-2', 'NBF2', 1, 'Active', '', 'Mutual Funds', 'prakash.basukala@nabilbank.com', '', NULL, NULL),
(173, 2840, '10.25% GLOBAL IME BANK LTD. DEBENTURE 2080/81', 'GBD80/81', 1, 'Active', '', 'Non-Convertible Debentures', 'bishnu.baskota@gibl.com.np', 'http://www.globalimebank.com', NULL, NULL),
(174, 2841, 'RASUWAGADHI HYDROPOWER COMPANY LIMITED', 'RHPL', 6, 'Active', '', 'Equity', 'rghpcl@gmail.com', 'www.rghpcl.com.np', NULL, NULL),
(175, 2842, 'SANJEN JALAVIDHYUT COMPANY LIMITED', 'SJCL', 6, 'Active', '', 'Equity', 'sanjenhcl@gmail.com', 'www.sjcl.com.np', NULL, NULL),
(176, 2843, 'SABAIKO LAGHUBITTA BITTIYA SANSTHA LIMITED', 'SABSL', 10, 'Active', '', 'Equity', 'info@sabaikolaghubitta.com', 'www.sabaikolaghubitta.com', NULL, NULL),
(177, 2850, '10 % NMB DEBENTURE 2085', 'NMBD2085', 1, 'Active', '', 'Non-Convertible Debentures', 'pramod.dahal@nmb.com.np', 'http://www.nmb.com.np', NULL, NULL),
(178, 2851, '10.5 % NEPAL INVESTMENT DEBENTURE 2082', 'NIBD2082', 1, 'Active', '', 'Non-Convertible Debentures', 'deepa@nibl.com.np', 'http://www.nibl.com.np', NULL, NULL),
(179, 2854, '10.25% NBBL Debenture 2085', 'NBBD2085', 1, 'Active', '', 'Non-Convertible Debentures', 'bishwapoudel@nbbl.com.np', '', NULL, NULL),
(180, 2859, 'Siddhartha Investment Growth Scheme - 2', 'SIGS2', 1, 'Active', '', 'Mutual Funds', 'laxman.ghimire@sbl.com.np', '', NULL, NULL),
(181, 2860, 'Saptakoshi Development Bank Ltd', 'SAPDBL', 3, 'Active', '', 'Equity', 'info@skdbl.com.np', 'www.skdbl.com.np', NULL, NULL),
(182, 2862, 'CITIZENS MUTUAL FUND 2', 'CMF2', 11, 'Active', '', 'Mutual Funds', 'info@cbilcapital.com', 'www.cbilcapital.com', NULL, NULL),
(183, 2863, 'NIC Asia Balanced Fund', 'NICBF', 11, 'Active', '', 'Mutual Funds', 'info@nicasiacapital.com', 'www.nicasiacapital.com', NULL, NULL),
(184, 2864, '10.25% SBL Debenture 2083', 'SBLD83', 1, 'Active', '', 'Non-Convertible Debentures', 'laxman.ghimire@sbl.com.np', '', NULL, NULL),
(185, 2866, '10.25% Machhapuchhre Bank Debenture 2085', 'MBLD2085', 1, 'Active', '', 'Non-Convertible Debentures', 'Tika.Bhattarai@mbl.com.np', 'http://www.machbank.com', NULL, NULL),
(186, 2867, 'NMB 50', 'NMB50', 11, 'Active', '', 'Mutual Funds', 'mutualfunds@nmbcl.com.np', 'www.nmbcl.com.np', NULL, NULL),
(187, 2868, '10.25% NIC Asia Debenture 2083/84', 'NICD83/84', 1, 'Active', '', 'Non-Convertible Debentures', 'suraj.shrestha3508@nicasiabank.com', '', NULL, NULL),
(188, 2869, '11% NIC Asia Debenture 082/83', 'NICAD8283', 1, 'Active', '', 'Non-Convertible Debentures', 'suraj.shrestha3508@nicasiabank.com', '', NULL, NULL),
(189, 2870, '8% BOK Debenture 2079', 'BOKD2079', 1, 'Active', '', 'Non-Convertible Debentures', 'deepak.gautam@bok.com.np', '', NULL, NULL),
(190, 2872, '10.50% SBL Debenture 2082', 'SBLD2082', 1, 'Active', '', 'Non-Convertible Debentures', 'laxman.ghimire@sbl.com.np', '', NULL, NULL),
(191, 2873, '10% Himalayan Bank Debenture 2083', 'HBLD83', 1, 'Active', '', 'Non-Convertible Debentures', 'bipin.hada@himalayanbank.com', '', NULL, NULL),
(192, 2875, '10.25% Prabhu Bank Debenture 2086', 'PBLD86', 1, 'Active', '', 'Non-Convertible Debentures', 'amit.bhandari@prabhubank.com', '', NULL, NULL),
(193, 2877, 'Sunrise First Mutual Fund', 'SFMF', 1, 'Active', '', 'Mutual Funds', 'ishwar.pathak@sunrisebank.com.np', '', NULL, NULL),
(194, 2878, '10.25% Sunrise Bank Debenture 2083', 'SRBLD83', 1, 'Active', '', 'Non-Convertible Debentures', 'ishwar.pathak@sunrisebank.com.np', '', NULL, NULL),
(195, 2879, '10% Laxmi Bank Debenture 2086', 'LBLD86', 1, 'Active', '', 'Non-Convertible Debentures', 'piyush.aryal@laxmibank.com', '', NULL, NULL),
(196, 2880, 'Himal Dolakha Hydropower Company Limited', 'HDHPC', 6, 'Active', '', 'Equity', 'hdhp@wlink.com.np', 'www.himaldolakhahydro.com', NULL, NULL),
(197, 2881, 'Nepal Reinsurance Company Limited', 'NRIC', 13, 'Active', '', 'Equity', 'nepalre@ntc.net.np', 'www.nepalre.com.np', NULL, NULL),
(198, 2882, '12% ICFC Finance Limited Debenture 2083', 'ICFCD83', 4, 'Active', '', 'Non-Convertible Debentures', 'sunil.pant@icfcbank.com', 'http://www.icfcbank.com', NULL, NULL),
(199, 2883, '12 % Goodwill Finance Limited Debenture 2083', 'GWFD83', 4, 'Active', '', 'Non-Convertible Debentures', 'gfcl@gfcl.com', '', NULL, NULL),
(200, 2885, '10.25% KBL Debenture 2086', 'KBLD86', 1, 'Active', '', 'Non-Convertible Debentures', 'info@kumaribank.com', 'http://www.kumaribank.com', NULL, NULL),
(201, 2886, '10.35% Agricultural Bank Debenture 2083', 'ADBLD83', 1, 'Active', '', 'Non-Convertible Debentures', 'cs@adbl.gov.np', '', NULL, NULL),
(202, 2887, 'NIC ASIA Laghubitta Bittiya Sanstha Limited', 'NICLBSL', 10, 'Active', '', 'Equity', 'prahlad.niraula@nicasiabank.com', 'www.nicasialaghubitta.com', NULL, NULL),
(203, 2889, '10.25% Citizens Bank Debenture 2086', 'CIZBD86', 1, 'Active', '', 'Non-Convertible Debentures', 'rajendra.shrestha@ctznbank.com', '', NULL, NULL),
(204, 2890, '10% Nepal SBI Bank Debenture 2086', 'SBIBD86', 1, 'Active', '', 'Non-Convertible Debentures', 'law@nsbl.com.np', '', NULL, NULL),
(205, 2892, '10% Nabil Debenture 2082', 'NBLD82', 1, 'Active', '', 'Non-Convertible Debentures', 'prakash.basukala@nabilbank.com', '', NULL, NULL),
(206, 2893, 'Ajod Insurance Limited', 'AIL', 12, 'Active', '', 'Equity', 'bp.upadhayay@ajodinsurance.com', 'www.ajodinsurance.com', NULL, NULL),
(207, 2895, '9% NIC Asia Debenture 2081/82', 'NICAD8182', 1, 'Active', '', 'Non-Convertible Debentures', 'suraj.shrestha3508@nicasiabank.com', '', NULL, NULL),
(208, 2896, 'Sadhana Laghubitta Bittiya Sanstha Limited', 'SDLBSL', 10, 'Active', '', 'Equity', 'resham.sadhana@gmail.com', 'www.sadhanlaghubitta.com.np', NULL, NULL),
(209, 2898, 'NRN Infrastructure and Development Limited', 'NRN', 7, 'Active', '', 'Equity', 'nrninvestmentltd@gmail.com', 'www.nrinl.com', NULL, NULL),
(210, 2900, 'Reliance Life Insurance Limited', 'RLI', 8, 'Active', '', 'Equity', 'muna@relifeinsurance.com', 'www.relifeinsurance.com', NULL, NULL),
(211, 2902, 'Laxmi Unnati Kosh', 'LUK', 11, 'Active', '', 'Mutual Funds', 'info@laxmicapital.com.np', 'www.laxmicapital.com.np', NULL, NULL),
(212, 2903, 'Liberty Energy Company Limited', 'LEC', 6, 'Active', '', 'Equity', 'liberty@libertyenergy.com.np', 'www.libertyenergy.com.np', NULL, NULL),
(213, 2904, '10% Prabhu Bank Debenture 2084', 'PBLD84', 1, 'Active', '', 'Non-Convertible Debentures', 'amit.bhandari@prabhubank.com', '', NULL, NULL),
(214, 2905, 'General Insurance Company Nepal Ltd', 'GIC', 12, 'Active', '', 'Equity', 'ram@generalinsurance.com.np', 'www.gicnepal.com', NULL, NULL),
(215, 2907, 'Shiva Shree Hydropower Ltd', 'SSHL', 6, 'Active', '', 'Equity', 'shivashreehydropowerltd@gmail.com', 'www.shivashreehdyro.com', NULL, NULL),
(216, 2908, 'Sanima General Insurance Limited', 'SGI', 12, 'Active', '', 'Equity', 'sanima@sanimageneral.com', 'www.sanimageneral.com', NULL, NULL),
(217, 2912, '8.5% SBL Debenture 2084', 'SBLD84', 1, 'Active', '', 'Non-Convertible Debentures', 'laxman.ghimire@sbl.com.np', '', NULL, NULL),
(218, 2913, 'Mountain Energy Nepal Limited', 'MEN', 6, 'Active', '', 'Equity', 'rajendra.sharma@mountainenergy.com.np', 'www.mountainenergy.com.np', NULL, NULL),
(219, 2914, 'United IDI Mardi RB Hydropower Limited.', 'UMRH', 6, 'Active', '', 'Equity', 'unitedidimardi7mw@gmail.com', 'www.idimardihydro.com.np', NULL, NULL),
(220, 2915, 'Prabhu Life Insurance Limited', 'PLI', 8, 'Active', '', 'Equity', 'info@prabhulife.com', 'www.prabhulife.com', NULL, NULL),
(221, 2917, 'Chandragiri Hills Limited', 'CGH', 5, 'Active', '', 'Equity', 'jhalak.sharma@chandragirihills.com', 'www.chandragirihills.com', NULL, NULL),
(222, 2919, 'Nepal Infrastructure Bank Limited', 'NIFRA', 7, 'Active', '', 'Equity', 'iswor.gautam@nifrabank.com', 'https://www.nifrabank.com', NULL, NULL),
(223, 2922, '8.5% Sanima Debenture 2087', 'SBD87', 1, 'Active', '', 'Non-Convertible Debentures', 'RUDRA@sanimabank.com', '', NULL, NULL),
(224, 2923, 'Sanima Large Cap Fund', 'SLCF', 1, 'Active', '', 'Mutual Funds', 'RUDRA@sanimabank.com', '', NULL, NULL),
(225, 2924, 'GreenLife Hydropower Limited', 'GLH', 6, 'Active', '', 'Equity', 'info@greenlifehydropower.com.np', 'www.greenlifehydropower.com.np', NULL, NULL),
(226, 2925, 'Mahila Lagubitta Bittiya Sanstha Limited', 'MLBSL', 10, 'Active', '', 'Equity', 'mlbsl.nepal@gmail.com', 'www.mlbsl.com.np', NULL, NULL),
(227, 2929, 'Jyoti Life Insurance Ltd', 'JLI', 8, 'Active', '', 'Equity', 'ram.thapaliya@jyotilife.com', 'www.jyotilife.com', NULL, NULL),
(228, 2931, '8.5% Nepal Investment Bank Debenture 2084', 'NIBD84', 1, 'Active', '', 'Non-Convertible Debentures', 'deepa@nibl.com.np', 'http://www.nibl.com.np', NULL, NULL),
(229, 2932, '9.5% Manjushree Finance Limited Debenture 2085', 'MFLD85', 4, 'Active', '', 'Non-Convertible Debentures', 'info@manjushreefinance.com.np', '', NULL, NULL),
(230, 2933, 'Kumari Equity Fund', 'KEF', 1, 'Active', '', 'Mutual Funds', 'info@kumaribank.com', 'http://www.kumaribank.com', NULL, NULL),
(231, 2934, 'Singati Hydro Energy Limited', 'SHEL', 6, 'Active', '', 'Equity', 'sudipkhadka321@gmail.com', 'www.singatihydro.com', NULL, NULL),
(232, 2935, 'Ru Ru Jalbidhyut Pariyojana Limited', 'RURU', 6, 'Active', '', 'Equity', 'contact@ruruhydro.com', 'www.ruruhydro.com', NULL, NULL),
(233, 2936, '9.5% NCC Debenture 2086', 'NCCD86', 1, 'Active', '', 'Non-Convertible Debentures', 'corporate@nccbank.com.np', 'http://www.nccbank.com.np', NULL, NULL),
(234, 2937, 'Sunrise Bluechip Fund', 'SBCF', 1, 'Active', '', 'Mutual Funds', 'ishwar.pathak@sunrisebank.com.np', '', NULL, NULL),
(235, 3946, 'CEDB Hydropower Development Company Limited', 'CHDC', 7, 'Active', '', 'Equity', 'chf@chf.com.np', 'www.chdc.com.np', NULL, NULL),
(236, 4947, 'Prabhu Select Fund', 'PSF', 1, 'Active', '', 'Mutual Funds', 'amit.bhandari@prabhubank.com', '', NULL, NULL),
(237, 4948, '9% Kamana Sewa Bikas Bank Limited Debenture 2087', 'KSBBLD87', 3, 'Active', '', 'Non-Convertible Debentures', 'hari.lamsal@kamanasewabank.com', '', NULL, NULL),
(238, 4949, 'NIBL Samriddhi Fund -2', 'NIBSF2', 1, 'Active', '', 'Mutual Funds', 'deepa@nibl.com.np', 'http://www.nibl.com.np', NULL, NULL),
(239, 4951, 'Jeevan Bikas Laghubitta Bittya Sanstha Ltd', 'JBLB', 10, 'Active', '', 'Equity', 'info@jeevanbikasmf.com', 'www.jeevanbikasmf.com', NULL, NULL),
(240, 4955, 'Manakamana Smart Laghubitta Bittiya Sanstha Limited', 'MKLB', 10, 'Active', '', 'Equity', 'manakamanalbs@gmail.com', 'www.manakamanalbs.com', NULL, NULL),
(241, 4956, 'Union Life Insurance Company Limited', 'ULI', 8, 'Active', '', 'Equity', 'kapil@unionlife.com.np', 'www.unionlife.com.np', NULL, NULL),
(242, 4959, '8.5% Nepal Bank Debenture 2087', 'NBLD87', 1, 'Active', '', 'Non-Convertible Debentures', 'suresh.ghimire@nbl.com.np', '', NULL, NULL),
(243, 4960, '4% Agricultural Bond', 'ADBLB', 1, 'Active', '', 'Non-Convertible Debentures', 'cs@adbl.gov.np', '', NULL, NULL),
(244, 4961, '8.5% BOK Debenture 2086', 'BOKD86', 1, 'Active', '', 'Non-Convertible Debentures', 'deepak.gautam@bok.com.np', '', NULL, NULL),
(245, 4962, '8.5% Prabhu Bank Debenture 2087', 'PBLD87', 1, 'Active', '', 'Non-Convertible Debentures', 'amit.bhandari@prabhubank.com', '', NULL, NULL),
(246, 4963, 'NMB Debenture 8.50% - 2087/88', 'NMBD87/88', 1, 'Active', '', 'Non-Convertible Debentures', 'pramod.dahal@nmb.com.np', 'http://www.nmb.com.np', NULL, NULL),
(247, 4964, 'NMB Energy Bond 4% - 2092/93', 'NMBEB92/93', 1, 'Active', '', 'Non-Convertible Debentures', 'pramod.dahal@nmb.com.np', 'http://www.nmb.com.np', NULL, NULL),
(248, 4967, 'NIC Asia Select Fund 30', 'NICSF', 11, 'Active', '', 'Mutual Funds', 'info@nicasiacapital.com', 'www.nicasiacapital.com', NULL, NULL),
(249, 4968, 'RBB Mutual Fund 1', 'RMF1', 11, 'Active', '', 'Mutual Funds', 'rbbmbl@rbbmbl.com.np', 'www.rbbmbl.com.np', NULL, NULL),
(250, 4969, 'Muktinath Debenture 2084/85', 'MND84/85', 3, 'Active', '', 'Non-Convertible Debentures', 'info@muktinathbank.com.np', '', NULL, NULL),
(251, 5982, 'Sanima Life Insurance Limited', 'SLI', 8, 'Active', '', 'Equity', 'sanima@sanimalife.com', 'www.sanimalife.com', NULL, NULL),
(252, 5984, '8.5% Laxmi Bank Debenture 2088', 'LBLD88', 1, 'Active', '', 'Non-Convertible Debentures', 'piyush.aryal@laxmibank.com', '', NULL, NULL),
(253, 6984, '8.75 % Prime Debenture 2085', 'PBD85', 1, 'Active', '', 'Non-Convertible Debentures', 'santosh.baral@pcbl.com.np', '', NULL, NULL),
(254, 6985, 'Shangri-la Development Bank Debenture 2087', 'SDBD87', 3, 'Active', '', 'Non-Convertible Debentures', 'info@shangrilabank.com', '', NULL, NULL),
(255, 7985, '8.5% Machhapuchchhre Debenture 2087', 'MBLD87', 1, 'Active', '', 'Non-Convertible Debentures', 'Tika.Bhattarai@mbl.com.np', 'http://www.machbank.com', NULL, NULL),
(256, 7986, 'NIC ASIA Rinpatra 2088', 'NICD88', 1, 'Active', '', 'Non-Convertible Debentures', 'suraj.shrestha3508@nicasiabank.com', '', NULL, NULL),
(257, 8003, '8.5% RBBL Debenture 2083', 'RBBD83', 1, 'Active', '', 'Non-Convertible Debentures', 'info.rbb@rbb.com.np', 'www.rbb.com.np', NULL, NULL);'''


with DataBase.cursor() as cursor:
    cursor.execute(insert_company_data)
    DataBase.commit()

# %%
import pandas as pd

# %%
data_url = pd.read_html("http://www.nepalstock.com/main/stockwiseprices/index/2/?startDate=2000-01-17&endDate=&stock-symbol=131&_limit=20000000")

# %%
dataset = pd.array(data_url)

# %%
print(dataset)

# %%
for rows in dataset:
    column = rows.values
    for columns in column:
        print(columns[0])
        insert_into_ohlc = ''' Insert into ohlc(Id, company_id, open, high, low, close, adj_close, volume, created_at, updated_at) VALUES(Null, columns[0],columns[1],columns[2],columns[3],columns[4], Null, Null,Null, Null);'''
        with DataBase.cursor() as cursor:
            cursor.execute(insert_into_ohlc)
            DataBase.commit()
# Out:
# Nabil Bank Limited Start Date  End Date  Stock Symbol  ... ... |  Total Rows  20 50 200 300 500  |
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     512                 query = query.encode('utf-8')
# --> 513             self._cmysql.query(query,
#     514                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '[0],columns[1],columns[2],columns[3],columns[4], Null, Null,Null, Null)' at line 1
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ...
